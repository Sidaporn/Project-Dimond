# %%
import random
import math 
from scipy.spatial import Delaunay
#from generativepy import drawing
#from generativepy.drawing import Color, ROUND

# %%
import numpy as np
from scipy.spatial import Delaunay
import matplotlib.pyplot as plt
def plotter(p):
    #data = image.imread('_Y_3_2/Project จบบบ/sourcecode/test.jpg')
    tri = Delaunay(p)
    plt.triplot(points[:,0], points[:,1], tri.simplices.copy())
    plt.plot(points[:,0], points[:,1], 'o')
    plt.show()

# %%
points = np.array([[-500, -500], [500, 500], [500, -500], [-500, 500]])
plotter(points) # displays triangulation!

# %%
points = np.append(points, [[-150, -100]], axis=0)
plotter(points)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
from PIL import Image

image = Image.open('test.jpg')
image.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('123.png')
imgplot = plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

x = [0, 2, 4, 6]
y = [1, 3, 4, 8]


plt.plot(x,y)


plt.xlabel('x values')
plt.ylabel('y values')
plt.title('plotted x and y values')
plt.legend(['line 1'])


# save the figure
plt.savefig('plot.png', dpi=300, bbox_inches='tight')


plt.show()

# %%
from scipy.spatial import Delaunay
SIZE = 800
points = [(random.randrange(SIZE), random.randrange(SIZE))for i in range(80)]

# %%
def triangle(canvas, a, b, c):
    color = random.choice(colors)
    canvas.fill(color)
    canvas.stroke(color)
    canvas.strokeWeight(1)
    canvas.triangle(*a, *b, *c)

# %%
from generativepy import drawing
def draw(canvas):
    random.seed(40)
    points = [(random.randrange(SIZE), random.randrange(SIZE))
               for i in range(80)]

    tri = Delaunay(points)
    for a, b, c in tri.simplices:
        triangle(canvas, points[a], points[b], points[c])

drawing.makeImage("delaunay-random-color.png", draw, pixelSize=(SIZE, SIZE),
                  background=Color(1, 1, 1))
